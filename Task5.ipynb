# %% [markdown]
# <a href="https://colab.research.google.com/github/tanushree2/summer-training/blob/main/Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:Tanushree Shah
#
# TASK-5
#
# Reg ID:GO_STP_7383

# %% [markdown]
# 1)Load the IMDb Dataset and read

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
df=pd.read_csv("/content/IMDB-Movie-Data.csv")

# %% [markdown]
# 2)View the dataset

# %%
df
# Out:
#      Rank                    Title  ... Revenue (Millions) Metascore
# 0       1  Guardians of the Galaxy  ...             333.13      76.0
# 1       2               Prometheus  ...             126.46      65.0
# 2       3                    Split  ...             138.12      62.0
# 3       4                     Sing  ...             270.32      59.0
# 4       5            Suicide Squad  ...             325.02      40.0
# ..    ...                      ...  ...                ...       ...
# 995   996     Secret in Their Eyes  ...                NaN      45.0
# 996   997          Hostel: Part II  ...              17.54      46.0
# 997   998   Step Up 2: The Streets  ...              58.01      50.0
# 998   999             Search Party  ...                NaN      22.0
# 999  1000               Nine Lives  ...              19.64      11.0
#
# [1000 rows x 12 columns]

# %% [markdown]
# 3)Understand some basic information about the dataset and Inspect the dataframe Inspect the dataframe's columns, shapes, variable types etc.

# %%
df.head()
# Out:
#    Rank                    Title  ... Revenue (Millions) Metascore
# 0     1  Guardians of the Galaxy  ...             333.13      76.0
# 1     2               Prometheus  ...             126.46      65.0
# 2     3                    Split  ...             138.12      62.0
# 3     4                     Sing  ...             270.32      59.0
# 4     5            Suicide Squad  ...             325.02      40.0
#
# [5 rows x 12 columns]

# %%
df.tail(50)
# Out:
#      Rank                           Title  ... Revenue (Millions) Metascore
# 950   951  Me and Earl and the Dying Girl  ...               6.74      74.0
# 951   952                 The Descendants  ...              82.62      84.0
# 952   953              Sex and the City 2  ...              95.33      27.0
# 953   954             The Kings of Summer  ...               1.29      61.0
# 954   955                      Death Race  ...              36.06      43.0
# 955   956             That Awkward Moment  ...              26.05      36.0
# 956   957                          Legion  ...              40.17      32.0
# 957   958                    End of Watch  ...              40.98      68.0
# 958   959                  3 Days to Kill  ...              30.69      40.0
# 959   960             Lucky Number Slevin  ...              22.49      53.0
# 960   961                          Trance  ...               2.32      61.0
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 12000

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.values
# Out:
# array([[1, 'Guardians of the Galaxy', 'Action,Adventure,Sci-Fi', ...,
#         757074, 333.13, 76.0],
#        [2, 'Prometheus', 'Adventure,Mystery,Sci-Fi', ..., 485820, 126.46,
#         65.0],
#        [3, 'Split', 'Horror,Thriller', ..., 157606, 138.12, 62.0],
#        ...,
#        [998, 'Step Up 2: The Streets', 'Drama,Music,Romance', ..., 70699,
#         58.01, 50.0],
#        [999, 'Search Party', 'Adventure,Comedy', ..., 4881, nan, 22.0],
#        [1000, 'Nine Lives', 'Comedy,Family,Fantasy', ..., 12435, 19.64,
#         11.0]], dtype=object)

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.describe()
# Out:
#               Rank         Year  ...  Revenue (Millions)   Metascore
# count  1000.000000  1000.000000  ...          872.000000  936.000000
# mean    500.500000  2012.783000  ...           82.956376   58.985043
# std     288.819436     3.205962  ...          103.253540   17.194757
# min       1.000000  2006.000000  ...            0.000000   11.000000
# 25%     250.750000  2010.000000  ...           13.270000   47.000000
# 50%     500.500000  2014.000000  ...           47.985000   59.500000
# 75%     750.250000  2016.000000  ...          113.715000   72.000000
# max    1000.000000  2016.000000  ...          936.630000  100.000000
#
# [8 rows x 7 columns]

# %%
df['Rating'].std()
# Out:
# 0.9454287892779637

# %%
df['Votes'].median()
# Out:
# 110799.0

# %%
df.sample()
# Out:
#      Rank       Title  ... Revenue (Millions) Metascore
# 387   388  Robin Hood  ...             105.22      53.0
#
# [1 rows x 12 columns]

# %%
df.dropna()
# Out:
#      Rank                     Title  ... Revenue (Millions) Metascore
# 0       1   Guardians of the Galaxy  ...             333.13      76.0
# 1       2                Prometheus  ...             126.46      65.0
# 2       3                     Split  ...             138.12      62.0
# 3       4                      Sing  ...             270.32      59.0
# 4       5             Suicide Squad  ...             325.02      40.0
# ..    ...                       ...  ...                ...       ...
# 993   994  Resident Evil: Afterlife  ...              60.13      37.0
# 994   995                 Project X  ...              54.72      48.0
# 996   997           Hostel: Part II  ...              17.54      46.0
# 997   998    Step Up 2: The Streets  ...              58.01      50.0
# 999  1000                Nine Lives  ...              19.64      11.0
#
# [838 rows x 12 columns]

# %% [markdown]
# 4) Data Selection – Indexing and Slicing data

# %%
df['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
df[['Title','Director']]
# Out:
#                        Title              Director
# 0    Guardians of the Galaxy            James Gunn
# 1                 Prometheus          Ridley Scott
# 2                      Split    M. Night Shyamalan
# 3                       Sing  Christophe Lourdelet
# 4              Suicide Squad            David Ayer
# ..                       ...                   ...
# 995     Secret in Their Eyes             Billy Ray
# 996          Hostel: Part II              Eli Roth
# 997   Step Up 2: The Streets            Jon M. Chu
# 998             Search Party        Scot Armstrong
# 999               Nine Lives      Barry Sonnenfeld
#
# [1000 rows x 2 columns]

# %%
df[50:100]
# Out:
#     Rank  ... Metascore
# 50    51  ...      81.0
# 51    52  ...      23.0
# 52    53  ...      18.0
# 53    54  ...      68.0
# 54    55  ...      82.0
# 55    56  ...      79.0
# 56    57  ...      71.0
# 57    58  ...      51.0
# 58    59  ...      76.0
# 59    60  ...      74.0
# 60    61  ...      44.0
# 61    62  ...      65.0
# 62    63  ...      48.0
# 63    64  ...      46.0
# 64    65  ...      66.0
# 65    66  ...      58.0
# 66    67  ...      69.0
# 67    68  ...      90.0
# 68    69  ...      61.0
# 69    70  ...      68.0
# 70    71  ...      49.0
# 71    72  ...      60.0
# 72    73  ...      76.0
# 73    74  ...      23.0
# 74    75  ...      78.0
# 75    76  ...      50.0
# 76    77  ...      69.0
# 77    78  ...      69.0
# 78    79  ...      53.0
# 79    80  ...      60.0
# 80    81  ...      74.0
# 81    82  ...      72.0
# 82    83  ...      75.0
# 83    84  ...      79.0
# 84    85  ...      67.0
# 85    86  ...      59.0
# 86    87  ...      49.0
# ...

# %%
df.iloc[10:50,[1,2,3]]
# Out:
#                                           Title  ...                                        Description
# 10      Fantastic Beasts and Where to Find Them  ...  The adventures of writer Newt Scamander in New...
# 11                               Hidden Figures  ...  The story of a team of female African-American...
# 12                                    Rogue One  ...  The Rebel Alliance makes a risky move to steal...
# 13                                        Moana  ...  In Ancient Polynesia, when a terrible curse in...
# 14                                     Colossal  ...  Gloria is an out-of-work party girl forced to ...
# 15                      The Secret Life of Pets  ...  The quiet life of a terrier named Max is upend...
# 16                                Hacksaw Ridge  ...  WWII American Army Medic Desmond T. Doss, who ...
# 17                                 Jason Bourne  ...  The CIA's most dangerous former operative is d...
# ...

# %%
df.loc[10:40,['Title']]
# Out:
#                                       Title
# 10  Fantastic Beasts and Where to Find Them
# 11                           Hidden Figures
# 12                                Rogue One
# 13                                    Moana
# 14                                 Colossal
# 15                  The Secret Life of Pets
# 16                            Hacksaw Ridge
# 17                             Jason Bourne
# 18                                     Lion
# 19                                  Arrival
# 20                                     Gold
# 21                    Manchester by the Sea
# 22                           Hounds of Love
# 23                                   Trolls
# 24             Independence Day: Resurgence
# 25                          Paris pieds nus
# 26                  Bahubali: The Beginning
# 27                               Dead Awake
# 28                                 Bad Moms
# 29                         Assassin's Creed
# ...

# %% [markdown]
# 5) Data Selection – Based on Conditional filtering

# %%
df1=df[df['Votes']>60000]
df1
# Out:
#      Rank                     Title  ... Revenue (Millions) Metascore
# 0       1   Guardians of the Galaxy  ...             333.13      76.0
# 1       2                Prometheus  ...             126.46      65.0
# 2       3                     Split  ...             138.12      62.0
# 3       4                      Sing  ...             270.32      59.0
# 4       5             Suicide Squad  ...             325.02      40.0
# ..    ...                       ...  ...                ...       ...
# 991   992          Taare Zameen Par  ...               1.20      42.0
# 993   994  Resident Evil: Afterlife  ...              60.13      37.0
# 994   995                 Project X  ...              54.72      48.0
# 996   997           Hostel: Part II  ...              17.54      46.0
# 997   998    Step Up 2: The Streets  ...              58.01      50.0
#
# [670 rows x 12 columns]

# %%
df2=df[df['Rating']>6]
df2
# Out:
#      Rank                    Title  ... Revenue (Millions) Metascore
# 0       1  Guardians of the Galaxy  ...             333.13      76.0
# 1       2               Prometheus  ...             126.46      65.0
# 2       3                    Split  ...             138.12      62.0
# 3       4                     Sing  ...             270.32      59.0
# 4       5            Suicide Squad  ...             325.02      40.0
# ..    ...                      ...  ...                ...       ...
# 991   992         Taare Zameen Par  ...               1.20      42.0
# 992   993     Take Me Home Tonight  ...               6.92       NaN
# 994   995                Project X  ...              54.72      48.0
# 995   996     Secret in Their Eyes  ...                NaN      45.0
# 997   998   Step Up 2: The Streets  ...              58.01      50.0
#
# [790 rows x 12 columns]

# %% [markdown]
# 6) Groupby operations

# %%
df.groupby('Title',sort=True)[['Rating']].mean()
# Out:
#                       Rating
# Title
# (500) Days of Summer     7.7
# 10 Cloverfield Lane      7.2
# 10 Years                 6.1
# 12 Years a Slave         8.1
# 127 Hours                7.6
# ...                      ...
# Zipper                   5.7
# Zodiac                   7.7
# Zombieland               7.7
# Zoolander 2              4.7
# Zootopia                 8.1
#
# [999 rows x 1 columns]

# %%
g = df.groupby('Genre')
g[['Revenue (Millions)']].std()
# Out:
#                             Revenue (Millions)
# Genre
# Action                                     NaN
# Action,Adventure                    136.038367
# Action,Adventure,Biography           12.006673
# Action,Adventure,Comedy             103.476124
# Action,Adventure,Crime               84.277317
# ...                                        ...
# Romance,Sci-Fi,Thriller                    NaN
# Sci-Fi                                     NaN
# Sci-Fi,Thriller                            NaN
# Thriller                                   NaN
# Thriller,War                               NaN
#
# [207 rows x 1 columns]

# %% [markdown]
# 7) Sorting operation

# %%
df_sorted=df.sort_values(by='Rating')
df_sorted
# Out:
#      Rank                    Title  ... Revenue (Millions) Metascore
# 829   830           Disaster Movie  ...              14.17      15.0
# 42     43  Don't Fuck in the Woods  ...                NaN       NaN
# 871   872     Dragonball Evolution  ...               9.35      45.0
# 647   648                 Tall Men  ...                NaN      57.0
# 968   969                  Wrecker  ...                NaN      37.0
# ..    ...                      ...  ...                ...       ...
# 36     37             Interstellar  ...             187.99      74.0
# 249   250         The Intouchables  ...              13.18      57.0
# 117   118                   Dangal  ...              11.15       NaN
# 80     81                Inception  ...             292.57      74.0
# 54     55          The Dark Knight  ...             533.32      82.0
#
# [1000 rows x 12 columns]

# %%
df.sort_index(ascending=False)
# Out:
#      Rank                    Title  ... Revenue (Millions) Metascore
# 999  1000               Nine Lives  ...              19.64      11.0
# 998   999             Search Party  ...                NaN      22.0
# 997   998   Step Up 2: The Streets  ...              58.01      50.0
# 996   997          Hostel: Part II  ...              17.54      46.0
# 995   996     Secret in Their Eyes  ...                NaN      45.0
# ..    ...                      ...  ...                ...       ...
# 4       5            Suicide Squad  ...             325.02      40.0
# 3       4                     Sing  ...             270.32      59.0
# 2       3                    Split  ...             138.12      62.0
# 1       2               Prometheus  ...             126.46      65.0
# 0       1  Guardians of the Galaxy  ...             333.13      76.0
#
# [1000 rows x 12 columns]

# %%
df_sorted1=df.sort_values(by=['Rank','Rating'],ascending=[True,False])
df_sorted1
# Out:
#      Rank                    Title  ... Revenue (Millions) Metascore
# 0       1  Guardians of the Galaxy  ...             333.13      76.0
# 1       2               Prometheus  ...             126.46      65.0
# 2       3                    Split  ...             138.12      62.0
# 3       4                     Sing  ...             270.32      59.0
# 4       5            Suicide Squad  ...             325.02      40.0
# ..    ...                      ...  ...                ...       ...
# 995   996     Secret in Their Eyes  ...                NaN      45.0
# 996   997          Hostel: Part II  ...              17.54      46.0
# 997   998   Step Up 2: The Streets  ...              58.01      50.0
# 998   999             Search Party  ...                NaN      22.0
# 999  1000               Nine Lives  ...              19.64      11.0
#
# [1000 rows x 12 columns]

# %% [markdown]
# 8) Dealing with missing values

# %%
df.isnull()
# Out:
#       Rank  Title  Genre  ...  Votes  Revenue (Millions)  Metascore
# 0    False  False  False  ...  False               False      False
# 1    False  False  False  ...  False               False      False
# 2    False  False  False  ...  False               False      False
# 3    False  False  False  ...  False               False      False
# 4    False  False  False  ...  False               False      False
# ..     ...    ...    ...  ...    ...                 ...        ...
# 995  False  False  False  ...  False                True      False
# 996  False  False  False  ...  False               False      False
# 997  False  False  False  ...  False               False      False
# 998  False  False  False  ...  False                True      False
# 999  False  False  False  ...  False               False      False
#
# [1000 rows x 12 columns]

# %% [markdown]
# 9) Dropping columns and null values

# %%
df.dropna()
# Out:
#      Rank                     Title  ... Revenue (Millions) Metascore
# 0       1   Guardians of the Galaxy  ...             333.13      76.0
# 1       2                Prometheus  ...             126.46      65.0
# 2       3                     Split  ...             138.12      62.0
# 3       4                      Sing  ...             270.32      59.0
# 4       5             Suicide Squad  ...             325.02      40.0
# ..    ...                       ...  ...                ...       ...
# 993   994  Resident Evil: Afterlife  ...              60.13      37.0
# 994   995                 Project X  ...              54.72      48.0
# 996   997           Hostel: Part II  ...              17.54      46.0
# 997   998    Step Up 2: The Streets  ...              58.01      50.0
# 999  1000                Nine Lives  ...              19.64      11.0
#
# [838 rows x 12 columns]

# %% [markdown]
# 10) Apply( ) functions

# %%
df["Rank"].apply(np.square)
# Out:
# 0            1
# 1            4
# 2            9
# 3           16
# 4           25
#         ...
# 995     992016
# 996     994009
# 997     996004
# 998     998001
# 999    1000000
# Name: Rank, Length: 1000, dtype: int64
